# %% [markdown]
# # Level 2: Conditions (11-20)

# %% [markdown]
# ### 11. Check if a number is even or odd

# %% [markdown]
# ### 12. Check if a number is positive, negative, or zero

# %% [markdown]
# ### 13. Find largest of two numbers

# %% [markdown]
# ### 14. Find largest of three numbers

# %% [markdown]
# ### 15. Check voting eligibility

# %% [markdown]
# ### 16. Grade calculator

# %% [markdown]
# ### 17. Check leap year

# %% [markdown]
# ### 18. Check if a year is a century year

# %% [markdown]
# ### 19. Build a simple calculator

# %% [markdown]
# ### 20. ATM withdrawal validation
